# %%
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = load_iris(as_frame=True).frame
pca = PCA(n_components=2)
iris[['new_feature_1', 'new_feature_2']] = pca.fit_transform(iris[['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']])

# %%
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
sns.scatterplot(data=iris, x="sepal length (cm)", y="sepal width (cm)", hue="target", palette=sns.color_palette("bright"))
plt.xlabel("sepal length (cm)", fontweight="bold", fontsize=15)
plt.ylabel("sepal width (cm)", fontweight="bold", fontsize=15)
plt.title("Iris Flower Dataset", fontweight="bold", fontsize=15)
# Out:
# C:\Users\Beltran Castro Gomez\AppData\Local\Temp\ipykernel_14436\3462950548.py:1: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(data=iris, x="sepal length (cm)", y="sepal width (cm)", hue="target", palette=sns.color_palette("bright"))
# Text(0.5, 1.0, 'Iris Flower Dataset')

# %%
sns.scatterplot(data=iris, x="new_feature_1", y="new_feature_2", hue="target", palette=sns.color_palette("bright"))
plt.xlabel("New X1 feature", fontweight="bold", fontsize=15)
plt.ylabel("New X2 feature", fontweight="bold", fontsize=15)
plt.title("PCA dimensionality reduction from 4D to 2D", fontweight="bold", fontsize=15)
# Out:
# C:\Users\Beltran Castro Gomez\AppData\Local\Temp\ipykernel_14436\4181694961.py:1: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   sns.scatterplot(data=iris, x="new_feature_1", y="new_feature_2", hue="target", palette=sns.color_palette("bright"))
# Text(0.5, 1.0, 'PCA dimensionality reduction from 4D to 2D')

# %%
# importing libraries 
import matplotlib.pyplot as plt 
import seaborn 
  
# declaring data 
data = [43, 39, 7, 6, 2, 2, 1] 
keys = ['Predicting Energy Prices', 'Predicting/Modeling Energy Consumption/Demand', 'Structure of Energy System', 'Policy Analysis', 'Model Calibration', 'Trading Strategies', 'Data Management'] 
  
# declaring exploding pie 
explode = [0.05, 0, 0, 0, 0, 0, 0] 
# define Seaborn color palette to use 
palette_color = seaborn.color_palette('bright') 
  
# plotting data on chart
plt.figure(figsize=(10,12))
plt.pie(data, labels=keys, 
        explode=explode, autopct='%.0f%%') 
  
# displaying chart 
plt.show()
